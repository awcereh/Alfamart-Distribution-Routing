# %%
pip install ortools
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ortools in c:\users\muham\appdata\roaming\python\python39\site-packages (9.8.3296)
# Requirement already satisfied: absl-py>=2.0.0 in c:\users\muham\appdata\roaming\python\python39\site-packages (from ortools) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\muham\appdata\roaming\python\python39\site-packages (from ortools) (1.23.4)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\muham\appdata\roaming\python\python39\site-packages (from ortools) (2.0.1)
# Requirement already satisfied: protobuf>=4.25.0 in c:\users\muham\appdata\roaming\python\python39\site-packages (from ortools) (4.25.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\muham\appdata\roaming\python\python39\site-packages (from pandas>=2.0.0->ortools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\muham\appdata\roaming\python\python39\site-packages (from pandas>=2.0.0->ortools) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\muham\appdata\roaming\python\python39\site-packages (from pandas>=2.0.0->ortools) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\muham\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\muham\appdata\roaming\python\python39\site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\muham\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\muham\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.9.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\muham\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\muham\appdata\roaming\python\python39\site-packages (from scikit-learn) (3.3.0)

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\muham\appdata\roaming\python\python39\site-packages (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\muham\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\muham\appdata\roaming\python\python39\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\muham\appdata\roaming\python\python39\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\muham\appdata\roaming\python\python39\site-packages (from pandas) (1.23.4)
# Requirement already satisfied: six>=1.5 in c:\users\muham\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from src.api_osmr import get_matrix, parse_coordinates
from src.routing import optimize_routes, plot_route

# %% [markdown]
# # Reading data

# %%
alpa = pd.read_csv("data/input/Data_Alfamart Indomaret_South Jakarta.csv")
alpa.head()
# Out:
#                     nama_tempat  rating_tempat  user_ratings_total  latitude
# 0                     indomaret            4.3                 104 -6.302203  \
# 1                     indomaret            0.0                   0 -6.307003
# 2            indomaret bdn raya            4.2                  66 -6.279392
# 3                     indomaret            4.7                   3 -6.278223
# 4  indomaret karang tengah raya            4.3                 108 -6.301344
#
#     longitude                                      alamat_tempat
# 0  106.791936  jl. lb. bulus iii no.40, rt.9/rw.7, cilandak b...  \
# 1  106.793690    10, rt.4/rw.10, pondok labu, south jakarta city
# 2  106.798442  jl. bdn raya no.10, rt.10/rw.11, cilandak bar....
# 3  106.797096  jl. rs. fatmawati raya no.7, rt.8/rw.6, gandar...
# 4  106.780550  bona indah plaza, jl. karang tengah raya no.1,...
#
#                       place_id      store                   place_id.1
# 0  ChIJaxj8TyDuaS4RmJ8rDkpB2GA  Indomaret  ChIJaxj8TyDuaS4RmJ8rDkpB2GA  \
# 1  ChIJPz4W5BPvaS4RoUnKBAiaL3o  Indomaret  ChIJPz4W5BPvaS4RoUnKBAiaL3o
# 2  ChIJKZqyypTxaS4RkjwUtyXrkBY  Indomaret  ChIJKZqyypTxaS4RkjwUtyXrkBY
# 3  ChIJzVqDlcTxaS4Rwlnqrz5hXbo  Indomaret  ChIJzVqDlcTxaS4Rwlnqrz5hXbo
# 4  ChIJ7aqqqinuaS4RKy68g0RuyMk  Indomaret  ChIJ7aqqqinuaS4RKy68g0RuyMk
#
#      nama_kelurahan nama_kecamatan             nama_kota
# 0    Cilandak Barat       Cilandak  Kota Jakarta Selatan
# 1       Pondok Labu       Cilandak  Kota Jakarta Selatan
# 2    Cilandak Barat       Cilandak  Kota Jakarta Selatan
# 3  Gandaria Selatan       Cilandak  Kota Jakarta Selatan
# 4       Lebak Bulus       Cilandak  Kota Jakarta Selatan

# %%
alpa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   nama_tempat         675 non-null    object
#  1   rating_tempat       675 non-null    float64
#  2   user_ratings_total  675 non-null    int64
#  3   latitude            675 non-null    float64
#  4   longitude           675 non-null    float64
#  5   alamat_tempat       675 non-null    object
#  6   place_id            675 non-null    object
#  7   store               675 non-null    object
#  8   place_id.1          675 non-null    object
#  9   nama_kelurahan      675 non-null    object
#  10  nama_kecamatan      675 non-null    object
#  11  nama_kota           675 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 63.4+ KB

# %%
alpa.head()
# Out:
#                     nama_tempat  rating_tempat  user_ratings_total  latitude
# 0                     indomaret            4.3                 104 -6.302203  \
# 1                     indomaret            0.0                   0 -6.307003
# 2            indomaret bdn raya            4.2                  66 -6.279392
# 3                     indomaret            4.7                   3 -6.278223
# 4  indomaret karang tengah raya            4.3                 108 -6.301344
#
#     longitude                                      alamat_tempat
# 0  106.791936  jl. lb. bulus iii no.40, rt.9/rw.7, cilandak b...  \
# 1  106.793690    10, rt.4/rw.10, pondok labu, south jakarta city
# 2  106.798442  jl. bdn raya no.10, rt.10/rw.11, cilandak bar....
# 3  106.797096  jl. rs. fatmawati raya no.7, rt.8/rw.6, gandar...
# 4  106.780550  bona indah plaza, jl. karang tengah raya no.1,...
#
#                       place_id      store                   place_id.1
# 0  ChIJaxj8TyDuaS4RmJ8rDkpB2GA  Indomaret  ChIJaxj8TyDuaS4RmJ8rDkpB2GA  \
# 1  ChIJPz4W5BPvaS4RoUnKBAiaL3o  Indomaret  ChIJPz4W5BPvaS4RoUnKBAiaL3o
# 2  ChIJKZqyypTxaS4RkjwUtyXrkBY  Indomaret  ChIJKZqyypTxaS4RkjwUtyXrkBY
# 3  ChIJzVqDlcTxaS4Rwlnqrz5hXbo  Indomaret  ChIJzVqDlcTxaS4Rwlnqrz5hXbo
# 4  ChIJ7aqqqinuaS4RKy68g0RuyMk  Indomaret  ChIJ7aqqqinuaS4RKy68g0RuyMk
#
#      nama_kelurahan nama_kecamatan             nama_kota
# 0    Cilandak Barat       Cilandak  Kota Jakarta Selatan
# 1       Pondok Labu       Cilandak  Kota Jakarta Selatan
# 2    Cilandak Barat       Cilandak  Kota Jakarta Selatan
# 3  Gandaria Selatan       Cilandak  Kota Jakarta Selatan
# 4       Lebak Bulus       Cilandak  Kota Jakarta Selatan

# %%
alpa.rename(columns={'longitude': 'lng'}, inplace=True)
alpa.rename(columns={'latitude': 'lat'}, inplace=True)

# %%
alpa
# Out:
#                       nama_tempat  rating_tempat  user_ratings_total
# 0                       indomaret            4.3                 104  \
# 1                       indomaret            0.0                   0
# 2              indomaret bdn raya            4.2                  66
# 3                       indomaret            4.7                   3
# 4    indomaret karang tengah raya            4.3                 108
# ..                            ...            ...                 ...
# 670       alfamart komplek selmis            0.0                   0
# 671   alfamart bukit duri selatan            0.0                   0
# 672               alfamart stasiu            5.0                   3
# 673            alfamart barkah ii            0.0                   0
# 674                      alfamart            4.5                 117
#
#           lat         lng                                      alamat_tempat
# 0   -6.302203  106.791936  jl. lb. bulus iii no.40, rt.9/rw.7, cilandak b...  \
# 1   -6.307003  106.793690    10, rt.4/rw.10, pondok labu, south jakarta city
# 2   -6.279392  106.798442  jl. bdn raya no.10, rt.10/rw.11, cilandak bar....
# 3   -6.278223  106.797096  jl. rs. fatmawati raya no.7, rt.8/rw.6, gandar...
# 4   -6.301344  106.780550  bona indah plaza, jl. karang tengah raya no.1,...
# ..        ...         ...                                                ...
# 670 -6.225834  106.858991  jl. asem baris raya no.3, rt.3/rw.9, kebon bar...
# 671 -6.221214  106.856739  jl. cucakrawa no.882, rt.8/rw.4, bukit duri, k...
# 672 -6.225869  106.858647  qvf5+mfc, flyover stasiun tebet, rt.3/rw.9, kb...
# 673 -6.219769  106.851183  jl. barkah i no.14, rw.6, manggarai sel., kota...
# 674 -6.224758  106.862924  jl. kp. melayu kecil no.17 a, rt.12/rw.9, buki...
#
#                         place_id      store                   place_id.1
# 0    ChIJaxj8TyDuaS4RmJ8rDkpB2GA  Indomaret  ChIJaxj8TyDuaS4RmJ8rDkpB2GA  \
# 1    ChIJPz4W5BPvaS4RoUnKBAiaL3o  Indomaret  ChIJPz4W5BPvaS4RoUnKBAiaL3o
# 2    ChIJKZqyypTxaS4RkjwUtyXrkBY  Indomaret  ChIJKZqyypTxaS4RkjwUtyXrkBY
# 3    ChIJzVqDlcTxaS4Rwlnqrz5hXbo  Indomaret  ChIJzVqDlcTxaS4Rwlnqrz5hXbo
# 4    ChIJ7aqqqinuaS4RKy68g0RuyMk  Indomaret  ChIJ7aqqqinuaS4RKy68g0RuyMk
# ..                           ...        ...                          ...
# 670  ChIJ0dPodPrzaS4RE47Rr8Mz77Y   Alfamart  ChIJ0dPodPrzaS4RE47Rr8Mz77Y
# 671  ChIJ8a2fcwfzaS4Rte3SBP5Gj_0   Alfamart  ChIJ8a2fcwfzaS4Rte3SBP5Gj_0
# 672  ChIJYRBiI-rzaS4RBW5LKzm2-yY   Alfamart  ChIJYRBiI-rzaS4RBW5LKzm2-yY
# 673  ChIJ85lVEnTzaS4RHy8f_3cmsuI   Alfamart  ChIJ85lVEnTzaS4RHy8f_3cmsuI
# 674  ChIJmxbt6ILzaS4RDljYoNQLKVc   Alfamart  ChIJmxbt6ILzaS4RDljYoNQLKVc
#
#         nama_kelurahan nama_kecamatan             nama_kota
# 0       Cilandak Barat       Cilandak  Kota Jakarta Selatan
# 1          Pondok Labu       Cilandak  Kota Jakarta Selatan
# 2       Cilandak Barat       Cilandak  Kota Jakarta Selatan
# 3     Gandaria Selatan       Cilandak  Kota Jakarta Selatan
# 4          Lebak Bulus       Cilandak  Kota Jakarta Selatan
# ..                 ...            ...                   ...
# 670         Kebon Baru          Tebet  Kota Jakarta Selatan
# 671         Bukit Duri          Tebet  Kota Jakarta Selatan
# 672         Kebon Baru          Tebet  Kota Jakarta Selatan
# 673  Manggarai Selatan          Tebet  Kota Jakarta Selatan
# 674         Bukit Duri          Tebet  Kota Jakarta Selatan
#
# [675 rows x 12 columns]

# %%
district = alpa.groupby(['nama_kecamatan'])[['lat','lng']].median().reset_index()
#district = alpa[['nama_kecamatan', 'lat', 'lng']].reset_index(drop=True)

# %%
district.head(15)
# Out:
#      nama_kecamatan       lat         lng
# 0          Cilandak -6.294267  106.794987
# 1         Jagakarsa -6.334303  106.821853
# 2    Kebayoran Baru -6.247656  106.798754
# 3    Kebayoran Lama -6.248754  106.778529
# 4  Mampang Prapatan -6.248328  106.821642
# 5          Pancoran -6.253804  106.850542
# 6      Pasar Minggu -6.289166  106.833580
# 7      Pesanggrahan -6.242619  106.756934
# 8         Setiabudi -6.214337  106.830171
# 9             Tebet -6.225853  106.855103

# %% [markdown]
# # Rute optimal untuk mengunjungi semua kecamatan (Alfamart dan Indomart)

# %%
# Extract the list of district from the "district" DataFrame
list_camat = district.nama_kecamatan

# Parse koordinat for the district
koordinat = parse_coordinates(district)

# Get the distance matrix for the district using the OSRM API
respon_jarak = get_matrix(koordinat)

# Convert the jarak to integer values (required by ortools)
jarak = np.array(respon_jarak["distances"]).astype(int)

# Set the starting nama_kecamatan for the route (change if needed)
camat_start = "Tebet"

# Find the index of the starting nama_kecamatan in the list_camat
index_depot = int(list_camat.index[list_camat == camat_start][0])

# Optimize the route using the distance matrix and starting nama_kecamatan index
rute_idx = optimize_routes(jarak, index_depot, list(list_camat))
# Out:
# Route for vehicle:
#  Tebet -> Pancoran -> Pasar Minggu -> Jagakarsa -> Cilandak -> Kebayoran Lama -> Pesanggrahan -> Kebayoran Baru -> Mampang Prapatan -> Setiabudi -> Tebet
# Route distance: 69.6km

# %%
# Create a DataFrame with the best route
alpa_best_rute = district.iloc[rute_idx]

# Get the koordinat of the best route
koordinat = list(zip(alpa_best_rute["lat"], alpa_best_rute["lng"]))

# Plot the best route on a Folium map
map_ku = plot_route(koordinat, dist=30000, zoom_start=11)
map_ku
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de5c0cc6484fb6dacde685313bdbfa16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de5c0cc6484fb6dacde685313bdbfa16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de5c0cc6484fb6dacde685313bdbfa16 = L.map(
#                 &quot;map_de5c0cc6484fb6dacde685313bdbfa16&quot;,
#                 {
#                     center: [-6.248328, 106.8216417],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f602bcaa0d49d43ceefae42017db010b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f602bcaa0d49d43ceefae42017db010b.addTo(map_de5c0cc6484fb6dacde685313bdbfa16);
#
#
#             var poly_line_2619f1dd478d63ea1f54bb42cf98669c = L.polyline(
#                 [[-6.2257793, 106.8553071], [-6.2262623, 106.8552986], [-6.2265672, 106.8553062], [-6.2268676, 106.8553322], [-6.22685, 106.8556875], [-6.2268348, 106.8559847], [-6.2268273, 106.8562784], [-6.2270627, 106.8562829], [-6.2273557, 106.8563912], [-6.2277927, 106.8566226], [-6.2279243, 106.8563592], [-6.2283352, 106.8565612], [-6.2285835, 106.8566945], [-6.2288598, 106.8568468], [-6.2290578, 106.8569206], [-6.2293599, 106.8569587], [-6.2300712, 106.8569574], [-6.2302443, 106.8572983], [-6.2303802, 106.8575865], [-6.2305377, 106.8578532], [-6.2306098, 106.8583382], [-6.2309578, 106.8583527], [-6.2313133, 106.8583685], [-6.2316023, 106.8583643], [-6.2318936, 106.8583696], [-6.232207, 106.85837], [-6.2324994, 106.8583675], [-6.2327911, 106.8583696], [-6.2330866, 106.8583729], [-6.2333855, 106.8583936], [-6.2336917, 106.8583948], [-6.2340955, 106.8583904], [-6.2345642, 106.8584263], [-6.234882, 106.8584429], [-6.2352073, 106.8584407], [-6.2352449, 106.8584396], [-6.2355097, 106.8584429], [-6.2358205, 106.8584417], [-6.2361133, 106.8584459], [-6.236413, 106.8584745], [-6.2367373, 106.8584766], [-6.2370621, 106.8584715], [-6.2373485, 106.8584727], [-6.2376336, 106.8584771], [-6.2379267, 106.8584857], [-6.2382254, 106.8584889], [-6.2385317, 106.858492], [-6.2388318, 106.8584938], [-6.239432, 106.8585044], [-6.2397275, 106.8585135], [-6.2400311, 106.8585277], [-6.2403676, 106.8585285], [-6.2407063, 106.8585352], [-6.2410457, 106.8585389], [-6.2413834, 106.8585445], [-6.2417091, 106.8585459], [-6.2420345, 106.8585515], [-6.2427296, 106.8584682], [-6.2428187, 106.8584467], [-6.2436234, 106.8584641], [-6.2444132, 106.8585906], [-6.2449451, 106.8586089], [-6.2452159, 106.8586081], [-6.2456704, 106.8586124], [-6.2459011, 106.8586184], [-6.2463457, 106.8585931], [-6.2486351, 106.8569969], [-6.2484378, 106.8565141], [-6.2484162, 106.8563154], [-6.250645, 106.8565166], [-6.2508854, 106.8564658], [-6.2511712, 106.8564532], [-6.2541211, 106.8554561], [-6.2541045, 106.8546032], [-6.2540433, 106.8514543], [-6.2540418, 106.8513765]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_de5c0cc6484fb6dacde685313bdbfa16);
#
#
#             ant_path_222e964045be604e1cc4752426926e54 = L.polyline.antPath(
#               [[-6.2257793, 106.8553071], [-6.2262623, 106.8552986], [-6.2265672, 106.8553062], [-6.2268676, 106.8553322], [-6.22685, 106.8556875], [-6.2268348, 106.8559847], [-6.2268273, 106.8562784], [-6.2270627, 106.8562829], [-6.2273557, 106.8563912], [-6.2277927, 106.8566226], [-6.2279243, 106.8563592], [-6.2283352, 106.8565612], [-6.2285835, 106.8566945], [-6.2288598, 106.8568468], [-6.2290578, 106.8569206], [-6.2293599, 106.8569587], [-6.2300712, 106.8569574], [-6.2302443, 106.8572983], [-6.2303802, 106.8575865], [-6.2305377, 106.8578532], [-6.2306098, 106.8583382], [-6.2309578, 106.8583527], [-6.2313133, 106.8583685], [-6.2316023, 106.8583643], [-6.2318936, 106.8583696], [-6.232207, 106.85837], [-6.2324994, 106.8583675], [-6.2327911, 106.8583696], [-6.2330866, 106.8583729], [-6.2333855, 106.8583936], [-6.2336917, 106.8583948], [-6.2340955, 106.8583904], [-6.2345642, 106.8584263], [-6.234882, 106.8584429], [-6.2352073, 106.8584407], [-6.2352449, 106.8584396], [-6.2355097, 106.8584429], [-6.2358205, 106.8584417], [-6.2361133, 106.8584459], [-6.236413, 106.8584745], [-6.2367373, 106.8584766], [-6.237

# %%
# saving interactive map in html (PEST API)
map_ku.save('maps/map_cities_route.html')

# %% [markdown]
# # Rute tidak pakai median

# %% [markdown]
# # Rute optimal untuk mengunjungi 10 titik dalam 1 kelurahan

# %%
# Iterate over each unique nama_kecamatan in the alpa data
for nama_kecamatan in alpa.nama_kecamatan.unique():
    print(f"Planning route for {nama_kecamatan}")

    # Select the first 10 points of sales for the current nama_kecamatan
    df_camat = alpa[alpa.nama_kecamatan == nama_kecamatan][:10].reset_index(drop=True)

    # Parse koordinat for the selected points of sales
    koordinat = parse_coordinates(df_camat)

    # Get the distance matrix for the selected points of sales using the OSRM API
    respon_jarak = get_matrix(koordinat)

    # Convert the jarak to integer values (required by ortools)
    jarak = np.array(respon_jarak["distances"]).astype(int)

    # Set the names of the points of sales for labeling the route
    nama_pos = list(df_camat.nama_kelurahan)

    # Setting the farthest point as the start point
    # Calculate the median tuple for the distance matrix
    tuples_koordinat = np.array(respon_jarak["distances"]).astype(int)
    tuple_median = tuple(np.median(np.array(tuples_koordinat), axis=0))

    # Calculate the Euclidean distance of each tuple from the median tuple
    tuple_jarak = [
        np.linalg.norm(np.array(t) - np.array(tuple_median)) for t in tuples_koordinat
    ]

    # Find the index of the tuple with the maximum distance
    index_farthest = max(enumerate(tuple_jarak), key=lambda x: x[1])[0]

    # Optimize the route using the distance matrix and farthest point index as the starting point
    rute_best = optimize_routes(jarak, index_farthest, nama_pos)[:-1]

    # Save the best route to a CSV file with the nama_kecamatan nama_kelurahan in the output folder
    df_camat.nama_kelurahan[rute_best].reset_index(drop=True).to_csv(
        f"data/output/{nama_kecamatan}_routing.csv"
    )

    # Plot the best route on the map for the nama_kecamatan "Tebet" (first nama_kecamatan in the iteration)
    if nama_kecamatan == "Mampang Prapatan":
        df_best_route = df_camat.iloc[rute_best]
        koordinat = list(zip(df_best_route["lat"], df_best_route["lng"]))
        map_ku = plot_route(koordinat, dist=2000)

# Display the final Folium map with the best route for the nama_kecamatan "Tebet"
map_ku
# Out:
# Planning route for Cilandak
# Route for vehicle:
#  Cilandak Barat -> Lebak Bulus -> Cilandak Barat -> Pondok Labu -> Pondok Labu -> Jati Padang -> Cilandak Barat -> Gandaria Selatan -> Gandaria Selatan -> Cilandak Barat -> Cilandak Barat
# Route distance: 14.0km
#
# Planning route for Jagakarsa
# Route for vehicle:
#  Srengseng Sawah -> Jagakarsa -> Jagakarsa -> Jagakarsa -> Jagakarsa -> Jagakarsa -> Jagakarsa -> Jagakarsa -> Ciganjur -> Cipedak -> Srengseng Sawah
# Route distance: 16.0km
#
# Planning route for Kebayoran Baru
# Route for vehicle:
#  Gandaria Utara -> Gandaria Utara -> Cipete Utara -> Cipete Utara -> Pulo -> Pulo -> Pulo -> Gandaria Utara -> Pulo -> Gandaria Utara -> Gandaria Utara
# Route distance: 7.8km
#
# Planning route for Kebayoran Lama
# Route for vehicle:
#  Kebayoran Lama Utara -> Kebayoran Lama Selatan -> Pondok Pinang -> Pondok Pinang -> Pondok Pinang -> Pondok Pinang -> Pondok Pinang -> Pondok Pinang -> Pondok Pinang -> Kebayoran Lama Selatan -> Kebayoran Lama Utara
# Route distance: 11.5km
#
# Planning route for Mampang Prapatan
# Route for vehicle:
#  Pela Mampang -> Pela Mampang -> Bangka -> Bangka -> Bangka -> Bangka -> Bangka -> Bangka -> Bangka -> Bangka -> Pela Mampang
# Route distance: 7.2km
#
# Planning route for Pancoran
# Route for vehicle:
#  Kalibata -> Kalibata -> Kalibata -> Duren Tiga -> Duren Tiga -> Duren Tiga -> Pancoran -> Pancoran -> Kalibata -> Kalibata -> Kalibata
# Route distance: 8.5km
#
# Planning route for Pasar Minggu
# Route for vehicle:
#  Cilandak Timur -> Cilandak Timur -> Ragunan -> Ragunan -> Ragunan -> Kebagusan -> Ragunan -> Pasar Minggu -> Kebagusan -> Pasar Minggu -> Cilandak Timur
# Route distance: 26.9km
#
# Planning route for Pesanggrahan
# Route for vehicle:
#  Pesanggrahan -> Petukangan Selatan -> Petukangan Selatan -> Petukangan Utara -> Ulujami -> Ulujami -> Ulujami -> Ulujami -> Petukangan Utara -> Petukangan Selatan -> Pesanggrahan
# Route distance: 9.8km
#
# Planning route for Setiabudi
# Route for vehicle:
#  Karet Kuningan -> Karet Kuningan -> Karet Semanggi -> Kuningan Timur -> Karet Kuningan -> Karet Kuningan -> Karet Kuningan -> Karet Kuningan -> Karet Kuningan -> Karet Kuningan -> Karet Kuningan
# Route distance: 13.2km
#
# Planning route for Tebet
# Route for vehicle:
#  Tebet Barat -> Tebet Barat -> Tebet Barat -> Menteng Dalam -> Menteng Dalam -> Menteng Dalam -> Menteng Dalam -> Menteng Dalam -> Menteng Dalam -> Manggarai Selatan -> Tebet Barat
# Route distance: 12.9km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d7ce0f65b8773a5dc8fa5a8fc640cde {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d7ce0f65b8773a5dc8fa5a8fc640cde&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d7ce0f65b8773a5dc8fa5a8fc640cde = L.map(
#                 &quot;map_3d7ce0f65b8773a5dc8fa5a8fc640cde&quot;,
#                 {
#                     center: [-6.2602656, 106.815172],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_718d6dd89e968c0a408fa6cc19a5b2a6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_718d6dd89e968c0a408fa6cc19a5b2a6.addTo(map_3d7ce0f65b8773a5dc8fa5a8fc640cde);
#
#
#             var poly_line_f5bbb88f48ed0dfd37eb49c0a3b6b177 = L.polyline(
#                 [[-6.2473821, 106.8151559], [-6.2480384, 106.8149627], [-6.2487237, 106.8147847], [-6.2488526, 106.8147549], [-6.2494516, 106.8146198], [-6.249889, 106.8145228], [-6.2519308, 106.8143941]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3d7ce0f65b8773a5dc8fa5a8fc640cde);
#
#
#             ant_path_fba99448fd5959defd77969fa5b40567 = L.polyline.antPath(
#               [[-6.2473821, 106.8151559], [-6.2480384, 106.8149627], [-6.2487237, 106.8147847], [-6.2488526, 106.8147549], [-6.2494516, 106.8146198], [-6.249889, 106.8145228], [-6.2519308, 106.8143941]],
#               {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: [10, 50], &quot;dashOffset&quot;: null, &quot;delay&quot;: 500, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;hardwareAcceleration&quot;: false, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;paused&quot;: false, &quot;pulseColor&quot;: &quot;#FFFFFF&quot;, &quot;reverse&quot;: false, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#         ).addTo(map_3d7ce0f65b8773a5dc8fa5a8fc640cde);
#
#
#             var poly_line_59bf208c579acd976656a294416566af = L.polyline(
#                 [[-6.2519308, 106.8143941], [-6.2520454, 106.8143901], [-6.2532992, 106.8144035], [-6.2546077, 106.8145511], [-6.2554075, 106.8147311]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3d7ce0f65b8773a5dc8fa5a8fc640cde);
#
#
#             ant_path_c40504181fd7f7c4943dca9156c40318 = L.polyline.antPath(
#               [[-6.2519308, 106.8143941], [-6.2520454, 106.8143901], [-6.2532992, 106.8144035], [-6.2546077, 106.8145511], [-6.2554075, 106.8147311]],
#               {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: [10, 50], &quot;dashOffset&quot;: null, &quot;delay&quot;: 500, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;hardwareAcceleration&quot;: false, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;paused&quot;: false, &quot;pulseColor&quot;: &quot;#FFFFFF&quot;, &quot;reverse&quot;: false, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#         ).addTo(map_3d7ce0f65b8773a5dc8fa5a8fc640cde);
#
#
#             var poly_line_785fe05c1c584f4737e7756ce6cfab40 = L.polyline(
#                 [[-6.2554075, 106.8147311], [-6.2565408, 106.8149103], [-6.2567541, 106.8149483], [-6.2574873, 106.8150543], [-6.2595889, 106.8153796], [-6.2607095, 106.8155808]],

# %%
# saving interactive map in html
map_ku.save('maps/map_tebet_route.html')

# %%
# Batasi setiap kecamatan menjadi 10 data
df_filtered = alpa.groupby('nama_kecamatan').head(10)

# Tampilkan DataFrame hasil filtering
df_filtered
# Out:
#                         nama_tempat  rating_tempat  user_ratings_total
# 0                         indomaret            4.3                 104  \
# 1                         indomaret            0.0                   0
# 2                indomaret bdn raya            4.2                  66
# 3                         indomaret            4.7                   3
# 4      indomaret karang tengah raya            4.3                 108
# ..                              ...            ...                 ...
# 613   indomaret tebet barat in tk29            4.2                 149
# 614           indomaret pal batu 36            4.3                  70
# 615                       indomaret            4.2                 421
# 616             indomaret al barkah            4.6                  18
# 617  indomaret apartemen casablanca            1.0                   1
#
#           lat         lng                                      alamat_tempat
# 0   -6.302203  106.791936  jl. lb. bulus iii no.40, rt.9/rw.7, cilandak b...  \
# 1   -6.307003  106.793690    10, rt.4/rw.10, pondok labu, south jakarta city
# 2   -6.279392  106.798442  jl. bdn raya no.10, rt.10/rw.11, cilandak bar....
# 3   -6.278223  106.797096  jl. rs. fatmawati raya no.7, rt.8/rw.6, gandar...
# 4   -6.301344  106.780550  bona indah plaza, jl. karang tengah raya no.1,...
# ..        ...         ...                                                ...
# 613 -6.238346  106.847226  jl. tebet barat dalam ivd no.88, rw.6, tebet b...
# 614 -6.224740  106.844751  jl. pal batu raya no.36, rt.13/rw.4, menteng d...
# 615 -6.229205  106.847449  jl. prof supomo no 321 blok bz persil no 19, r...
# 616 -6.220490  106.847233  jl. albarkah no.20, rt.7/rw.3, manggarai sel.,...
# 617 -6.223299  106.845345  jl. raya casablanca no.14, rw.5, menteng dalam...
#
#                         place_id      store                   place_id.1
# 0    ChIJaxj8TyDuaS4RmJ8rDkpB2GA  Indomaret  ChIJaxj8TyDuaS4RmJ8rDkpB2GA  \
# 1    ChIJPz4W5BPvaS4RoUnKBAiaL3o  Indomaret  ChIJPz4W5BPvaS4RoUnKBAiaL3o
# 2    ChIJKZqyypTxaS4RkjwUtyXrkBY  Indomaret  ChIJKZqyypTxaS4RkjwUtyXrkBY
# 3    ChIJzVqDlcTxaS4Rwlnqrz5hXbo  Indomaret  ChIJzVqDlcTxaS4Rwlnqrz5hXbo
# 4    ChIJ7aqqqinuaS4RKy68g0RuyMk  Indomaret  ChIJ7aqqqinuaS4RKy68g0RuyMk
# ..                           ...        ...                          ...
# 613  ChIJ7ahV373zaS4Rm9rs7VrGTVg  Indomaret  ChIJ7ahV373zaS4Rm9rs7VrGTVg
# 614  ChIJtX8wqY3zaS4RTpmMPQzAFbg  Indomaret  ChIJtX8wqY3zaS4RTpmMPQzAFbg
# 615  ChIJxf__P5bzaS4RZ7KfkYohoDc  Indomaret  ChIJxf__P5bzaS4RZ7KfkYohoDc
# 616  ChIJk___P4nzaS4RKHnkXKOuy64  Indomaret  ChIJk___P4nzaS4RKHnkXKOuy64
# 617  ChIJV4P3VhjzaS4RnuDMhqW9W2w  Indomaret  ChIJV4P3VhjzaS4RnuDMhqW9W2w
#
#         nama_kelurahan nama_kecamatan             nama_kota
# 0       Cilandak Barat       Cilandak  Kota Jakarta Selatan
# 1          Pondok Labu       Cilandak  Kota Jakarta Selatan
# 2       Cilandak Barat       Cilandak  Kota Jakarta Selatan
# 3     Gandaria Selatan       Cilandak  Kota Jakarta Selatan
# 4          Lebak Bulus       Cilandak  Kota Jakarta Selatan
# ..                 ...            ...                   ...
# 613        Tebet Barat          Tebet  Kota Jakarta Selatan
# 614      Menteng Dalam          Tebet  Kota Jakarta Selatan
# 615        Tebet Barat          Tebet  Kota Jakarta Selatan
# 616  Manggarai Selatan          Tebet  Kota Jakarta Selatan
# 617      Menteng Dalam          Tebet  Kota Jakarta Selatan
#
# [100 rows x 12 columns]

# %%
# Simpan DataFrame hasil filtering ke file CSV
df_filtered.to_csv('Data_Alfamart Indomaret_South Jakarta_Filtered.csv', index=False)

# %%
df_filtered.head(100)
# Out:
#                         nama_tempat  rating_tempat  user_ratings_total
# 0                         indomaret            4.3                 104  \
# 1                         indomaret            0.0                   0
# 2                indomaret bdn raya            4.2                  66
# 3                         indomaret            4.7                   3
# 4      indomaret karang tengah raya            4.3                 108
# ..                              ...            ...                 ...
# 613   indomaret tebet barat in tk29            4.2                 149
# 614           indomaret pal batu 36            4.3                  70
# 615                       indomaret            4.2                 421
# 616             indomaret al barkah            4.6                  18
# 617  indomaret apartemen casablanca            1.0                   1
#
#           lat         lng                                      alamat_tempat
# 0   -6.302203  106.791936  jl. lb. bulus iii no.40, rt.9/rw.7, cilandak b...  \
# 1   -6.307003  106.793690    10, rt.4/rw.10, pondok labu, south jakarta city
# 2   -6.279392  106.798442  jl. bdn raya no.10, rt.10/rw.11, cilandak bar....
# 3   -6.278223  106.797096  jl. rs. fatmawati raya no.7, rt.8/rw.6, gandar...
# 4   -6.301344  106.780550  bona indah plaza, jl. karang tengah raya no.1,...
# ..        ...         ...                                                ...
# 613 -6.238346  106.847226  jl. tebet barat dalam ivd no.88, rw.6, tebet b...
# 614 -6.224740  106.844751  jl. pal batu raya no.36, rt.13/rw.4, menteng d...
# 615 -6.229205  106.847449  jl. prof supomo no 321 blok bz persil no 19, r...
# 616 -6.220490  106.847233  jl. albarkah no.20, rt.7/rw.3, manggarai sel.,...
# 617 -6.223299  106.845345  jl. raya casablanca no.14, rw.5, menteng dalam...
#
#                         place_id      store                   place_id.1
# 0    ChIJaxj8TyDuaS4RmJ8rDkpB2GA  Indomaret  ChIJaxj8TyDuaS4RmJ8rDkpB2GA  \
# 1    ChIJPz4W5BPvaS4RoUnKBAiaL3o  Indomaret  ChIJPz4W5BPvaS4RoUnKBAiaL3o
# 2    ChIJKZqyypTxaS4RkjwUtyXrkBY  Indomaret  ChIJKZqyypTxaS4RkjwUtyXrkBY
# 3    ChIJzVqDlcTxaS4Rwlnqrz5hXbo  Indomaret  ChIJzVqDlcTxaS4Rwlnqrz5hXbo
# 4    ChIJ7aqqqinuaS4RKy68g0RuyMk  Indomaret  ChIJ7aqqqinuaS4RKy68g0RuyMk
# ..                           ...        ...                          ...
# 613  ChIJ7ahV373zaS4Rm9rs7VrGTVg  Indomaret  ChIJ7ahV373zaS4Rm9rs7VrGTVg
# 614  ChIJtX8wqY3zaS4RTpmMPQzAFbg  Indomaret  ChIJtX8wqY3zaS4RTpmMPQzAFbg
# 615  ChIJxf__P5bzaS4RZ7KfkYohoDc  Indomaret  ChIJxf__P5bzaS4RZ7KfkYohoDc
# 616  ChIJk___P4nzaS4RKHnkXKOuy64  Indomaret  ChIJk___P4nzaS4RKHnkXKOuy64
# 617  ChIJV4P3VhjzaS4RnuDMhqW9W2w  Indomaret  ChIJV4P3VhjzaS4RnuDMhqW9W2w
#
#         nama_kelurahan nama_kecamatan             nama_kota
# 0       Cilandak Barat       Cilandak  Kota Jakarta Selatan
# 1          Pondok Labu       Cilandak  Kota Jakarta Selatan
# 2       Cilandak Barat       Cilandak  Kota Jakarta Selatan
# 3     Gandaria Selatan       Cilandak  Kota Jakarta Selatan
# 4          Lebak Bulus       Cilandak  Kota Jakarta Selatan
# ..                 ...            ...                   ...
# 613        Tebet Barat          Tebet  Kota Jakarta Selatan
# 614      Menteng Dalam          Tebet  Kota Jakarta Selatan
# 615        Tebet Barat          Tebet  Kota Jakarta Selatan
# 616  Manggarai Selatan          Tebet  Kota Jakarta Selatan
# 617      Menteng Dalam          Tebet  Kota Jakarta Selatan
#
# [100 rows x 12 columns]

# %%
district_new = df_filtered.groupby(['nama_kecamatan'])[['lat','lng']].median().reset_index()
#district = alpa[['nama_kecamatan', 'lat', 'lng']].reset_index(drop=True)

# %%
district_new
# Out:
#      nama_kecamatan       lat         lng
# 0          Cilandak -6.291939  106.794654
# 1         Jagakarsa -6.326346  106.813516
# 2    Kebayoran Baru -6.255412  106.797106
# 3    Kebayoran Lama -6.277502  106.780020
# 4  Mampang Prapatan -6.260986  106.814743
# 5          Pancoran -6.256501  106.836620
# 6      Pasar Minggu -6.296401  106.822389
# 7      Pesanggrahan -6.239295  106.757464
# 8         Setiabudi -6.221750  106.826085
# 9             Tebet -6.227106  106.845048

# %%
# Extract the list of district_new from the "district_new" DataFrame
list_camat = district_new.nama_kecamatan

# Parse koordinat for the district_new
koordinat = parse_coordinates(district_new)

# Get the distance matrix for the district_new using the OSRM API
respon_jarak = get_matrix(koordinat)

# Convert the jarak to integer values (required by ortools)
jarak = np.array(respon_jarak["distances"]).astype(int)

# Set the starting nama_kecamatan for the route (change if needed)
camat_start = "Tebet"

# Find the index of the starting nama_kecamatan in the list_camat
index_depot = int(list_camat.index[list_camat == camat_start][0])

# Optimize the route using the distance matrix and starting nama_kecamatan index
rute_idx = optimize_routes(jarak, index_depot, list(list_camat))
# Out:
# Route for vehicle:
#  Tebet -> Pancoran -> Mampang Prapatan -> Kebayoran Baru -> Pesanggrahan -> Kebayoran Lama -> Cilandak -> Pasar Minggu -> Jagakarsa -> Setiabudi -> Tebet
# Route distance: 61.6km

# %%
# Create a DataFrame with the best route
alpa_best_rute = district_new.iloc[rute_idx]

# Get the koordinat of the best route
koordinat = list(zip(alpa_best_rute["lat"], alpa_best_rute["lng"]))

# Plot the best route on a Folium map
map_ku = plot_route(koordinat, dist=30000, zoom_start=11)
map_ku
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7216e8563337fdd2e4010fb414092975 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7216e8563337fdd2e4010fb414092975&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7216e8563337fdd2e4010fb414092975 = L.map(
#                 &quot;map_7216e8563337fdd2e4010fb414092975&quot;,
#                 {
#                     center: [-6.2609861, 106.8147428],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6dd0f05d7e30cea42a3e9fa4eee90264 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6dd0f05d7e30cea42a3e9fa4eee90264.addTo(map_7216e8563337fdd2e4010fb414092975);
#
#
#             var poly_line_c5ad5b7353475e5b0b84675387b52ace = L.polyline(
#                 [[-6.2266581, 106.8447353], [-6.2280737, 106.8448113], [-6.2284327, 106.8448241], [-6.228338, 106.8454616], [-6.2283265, 106.8455625], [-6.2287135, 106.8456383], [-6.2288325, 106.8464921], [-6.2289333, 106.8472353], [-6.2289516, 106.8473589], [-6.2305878, 106.8468515], [-6.2312211, 106.8461648], [-6.2316697, 106.8456525], [-6.2355659, 106.8442924], [-6.2373675, 106.8444731], [-6.2379026, 106.8446696], [-6.2395822, 106.8455282], [-6.241303, 106.8447313], [-6.2422615, 106.8441237], [-6.2426084, 106.8439473], [-6.2428438, 106.8438351], [-6.2435629, 106.8435604], [-6.2439106, 106.8434143], [-6.245993, 106.8428846], [-6.2461323, 106.8428705], [-6.246181, 106.8428671], [-6.2468022, 106.8428376], [-6.2488292, 106.8427873], [-6.2496698, 106.8427666], [-6.2519141, 106.8425876], [-6.25353, 106.8425561], [-6.2535299, 106.8424861], [-6.2535432, 106.8406899], [-6.2535492, 106.8404438], [-6.2540611, 106.8404424], [-6.255131, 106.8404236], [-6.2551263, 106.8398818], [-6.255175, 106.8386634], [-6.2562513, 106.838239], [-6.2561281, 106.837728], [-6.2561508, 106.8371309], [-6.2559452, 106.8371272], [-6.2559628, 106.8365391], [-6.2566001, 106.8365928]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7216e8563337fdd2e4010fb414092975);
#
#
#             ant_path_9ceb3da7157aef72f50413a06fe354e0 = L.polyline.antPath(
#               [[-6.2266581, 106.8447353], [-6.2280737, 106.8448113], [-6.2284327, 106.8448241], [-6.228338, 106.8454616], [-6.2283265, 106.8455625], [-6.2287135, 106.8456383], [-6.2288325, 106.8464921], [-6.2289333, 106.8472353], [-6.2289516, 106.8473589], [-6.2305878, 106.8468515], [-6.2312211, 106.8461648], [-6.2316697, 106.8456525], [-6.2355659, 106.8442924], [-6.2373675, 106.8444731], [-6.2379026, 106.8446696], [-6.2395822, 106.8455282], [-6.241303, 106.8447313], [-6.2422615, 106.8441237], [-6.2426084, 106.8439473], [-6.2428438, 106.8438351], [-6.2435629, 106.8435604], [-6.2439106, 106.8434143], [-6.245993, 106.8428846], [-6.2461323, 106.8428705], [-6.246181, 106.8428671], [-6.2468022, 106.8428376], [-6.2488292, 106.8427873], [-6.2496698, 106.8427666], [-6.2519141, 106.8425876], [-6.25353, 106.8425561], [-6.2535299, 106.8424861], [-6.2535432, 106.8406899], [-6.2535492, 106.8404438], [-6.2540611, 106.8404424], [-6.255131, 106.8404236], [-6.2551263, 106.8398818], [-6.255175, 106.8386634], [-6.2562513, 106.838239], [-6.2561281, 106.837728], [-6.2561508, 106.8371309], [-6.2559452, 106.8371272], [-6.2559628, 106.8365391], [-6.2566001, 106.8365928]],
#               {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: [10, 50], &quot;dashOffset&quot;: null, &quot;delay&quot;: 500, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;hardwareAcceleration&quot;: false, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;paused&quot;: false, &quot;pulseColor&quot;: &quot;#FFFFFF&quot;, &quot;reverse&quot;: false, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#         ).addTo(map_7216e8563337fdd2e4010fb414092975);
#
#
#             var poly_line_298fb8111a994224a67be4493834032f = L.polyline(
#                 [[-6.2566001, 1

# %%
# Iterate over each unique nama_kecamatan in the df_filtered data
for nama_kecamatan in df_filtered.nama_kecamatan.unique():
    print(f"Planning route for {nama_kecamatan}")

    # Select the first 10 points of sales for the current nama_kecamatan
    df_camat = df_filtered[df_filtered.nama_kecamatan == nama_kecamatan][:11].reset_index(drop=True)

    # Parse koordinat for the selected points of sales
    koordinat = parse_coordinates(df_camat)

    # Get the distance matrix for the selected points of sales using the OSRM API
    respon_jarak = get_matrix(koordinat)

    # Convert the jarak to integer values (required by ortools)
    jarak = np.array(respon_jarak["distances"]).astype(int)

    # Set the names of the points of sales for labeling the route
    nama_pos = list(df_camat.alamat_tempat)

    # Setting the farthest point as the start point
    # Calculate the median tuple for the distance matrix
    tuples_koordinat = np.array(respon_jarak["distances"]).astype(int)
    tuple_median = tuple(np.median(np.array(tuples_koordinat), axis=0))

    # Calculate the Euclidean distance of each tuple from the median tuple
    tuple_jarak = [
        np.linalg.norm(np.array(t) - np.array(tuple_median)) for t in tuples_koordinat
    ]

    # Find the index of the tuple with the maximum distance
    index_farthest = max(enumerate(tuple_jarak), key=lambda x: x[1])[0]

    # Optimize the route using the distance matrix and farthest point index as the starting point
    rute_best = optimize_routes(jarak, index_farthest, nama_pos)[:-1]

    # Save the best route to a CSV file with the nama_kecamatan alamat_tempat in the output folder
    df_camat.alamat_tempat[rute_best].reset_index(drop=True).to_csv(
        f"data/output/{nama_kecamatan}_routing.csv"
    )

    # Plot the best route on the map for the nama_kecamatan "Tebet" (first nama_kecamatan in the iteration)
    if nama_kecamatan == "Tebet":
        df_best_route = df_camat.iloc[rute_best]
        koordinat = list(zip(df_best_route["lat"], df_best_route["lng"]))
        map_ku = plot_route(koordinat, dist=2000)

# Display the final Folium map with the best route for the nama_kecamatan "Tebet"
map_ku
# Out:
# Planning route for Cilandak
# Route for vehicle:
#  pq4v+vph, jl. r.a. kartini, rt.1/rw.4, cilandak bar., kota jakarta selatan -> bona indah plaza, jl. karang tengah raya no.1, rt.5/rw.4, lb. bulus, kota jakarta selatan -> jl. lb. bulus iii no.40, rt.9/rw.7, cilandak bar., kota jakarta selatan -> 10, rt.4/rw.10, pondok labu, south jakarta city -> jl. rs. fatmawati raya no.26, rt.1/rw.7, pd. labu, kota jakarta selatan -> jl. pejaten raya no.19 a, rt.18/rw.2, jati padang, kota jakarta selatan -> jl. terogong raya no.16, rt.10/rw.10, cilandak bar., kota jakarta selatan -> jl. rs. fatmawati raya no.7, rt.8/rw.6, gandaria sel., kota jakarta selatan -> jl. rs. fatmawati no. 15 ab gandaria selatan cilandak jakarta selatan dki jakarta rt.8, rw.6, gandaria sel., kota jakarta selatan -> jl. bdn raya no.10, rt.10/rw.11, cilandak bar., kota jakarta selatan -> pq4v+vph, jl. r.a. kartini, rt.1/rw.4, cilandak bar., kota jakarta selatan
# Route distance: 14.0km
#
# Planning route for Jagakarsa
# Route for vehicle:
#  jl. yon zikon 14 no.1-32, rt.6/rw.6, srengseng sawah, kota jakarta selatan -> mr9c+35v, townhouse jagakarsa, jl. jagakarsa 1, rt.3/rw.2, jagakarsa, kota jakarta selatan -> jl. pepaya raya no.4, rt.2/rw.5, jagakarsa, kota jakarta selatan -> no., jl. raya jagakarsa no.2, rt.10/rw.2, jagakarsa, kota jakarta selatan -> jl. paso no.32, rt.4/rw.4, jagakarsa, kota jakarta selatan -> jalan jagakarsa blok hidayah no.10 rt.10/rw.6, rt.3/rw.6, jagakarsa, kota jakarta selatan -> jl. m. khafi no.62, rt.3/rw.4, jagakarsa, kota jakarta selatan -> jl. m.kahfi 1 rt 01/rw 04, jagakarsa, jagakarsa, rt.2/rw.7, jagakarsa, south jakarta city -> jl. m. khafi no.5, rt.8/rw.6, ciganjur, kota jakarta selatan -> jl. timbul no.37, rt.1/rw.3, cipedak, kota jakarta selatan -> jl. yon zikon 14 no.1-32, rt.6/rw.6, srengseng sawah, kota jakarta selatan
# Route distance: 16.0km
#
# Planning route for Kebayoran Baru
# Route for vehicle:
#  jl. bri radio dalam no.83, rt.1/rw.8, gandaria utara, kota jakarta selatan -> jl. radio dalam raya no.12a, rt.7/rw.10, gandaria utara, kota jakarta selatan -> jl. rs. fatmawati raya no.15, rw.5, cipete utara, kota jakarta selatan -> pqpx+9g4, unnamed road, rt.1/rw.5, north cipete, south jakarta city -> jl. darmawangsa raya no.125, rt.2, rt.2/rw.1, pulo, kota jakarta selatan -> jl. panglima polim no.125a, rt.2/rw.1, pulo, kota jakarta selatan -> grand wijaya blok b10, jl. wijaya ii, rt.6/rw.1, pulo, kota jakarta selatan -> jl. rs. fatmawati raya no.1, gandaria utara, kota jakarta selatan -> jl. petogogan ii no.18, rt.9/rw.5, pulo, kota jakarta selatan -> jl. radio dalam raya blok haji hamali no.22, rt.1/rw.9, gandaria utara, kota jakarta selatan -> jl. bri radio dalam no.83, rt.1/rw.8, gandaria utara, kota jakarta selatan
# Route distance: 7.8km
#
# Planning route for Kebayoran Lama
# Route for vehicle:
#  jl. pahlawan no.2, rw.10, kby. lama utara, kota jakarta selatan -> gg. swadaya iii no.18, rt.10/rw.9, kby. lama sel., kota jakarta selatan -> blok tc, jl. metro pondok indah no.11, rt.2/rw.15, pd. pinang, kota jakarta selatan -> pq7j+p92, jl. metro pondok indah, rt.3/rw.14, pd. pinang, kota jakarta selatan -> jl. taman duta i no.7, rt.4/rw.14, pd. pinang, kota jakarta selatan -> jl. ciputat raya no.4, rt.9/rw.2, pd. pinang, kota jakarta selatan -> jl. ciputat raya 24 rt 009 rw 002, pondok pinang, kebayoran lama, rt.11/rw.15, pondok pinang, south jakarta city -> jl. ciputat raya no.01, rt.11/rw.15, pd. pinang, kota jakarta selatan -> pertokoan taman hijau baru, jalan bukit hijau 1 no. 14, pondok pinang, kebayoran lama, rt.1/rw.13, pd. pinang, kota jakarta selatan -> jl. ciputat raya no.35, rw.10, kby. lama sel., kota jakarta selatan -> jl. pahlawan no.2, rw.10, kby. lama utara, kota jakarta selatan
# Route distance: 11.5km
#
# Planning route for Mampang Prapatan
# Route for vehicle:
#  jl. bangka iig no.11, rw.11, pela mampang, kota jakarta selatan -> jl. bangka raya no.105, rt.1/rw.12, pela mampang, kota jakarta selatan -> jl. bangka raya no.5d, rt.13/rw.1, bangka, kota jakarta selatan -> jl. kemang raya no.8, rt.8/rw.2, bangka, kota jakarta selatan -> jl. kemang raya no.36, rt.12/rw.5, bangka, kota jakarta selatan -> jl. taman kemang jaya no.9, rw.2, bangka, kota jakarta selatan -> jl. kemang raya no.128, rt.3/rw.2, bangka, kota jakarta selatan -> jl. kemang selatan viii no.67f, rt.7/rw.2, bangka, kota jakarta selatan -> spbu kemang, jl. kemang raya no.7, rw.2, bangka, kota jakarta selatan -> jl. kemang raya no.15, rt.13/rw.1, bangka, kota jakarta selatan -> jl. bangka iig no.11, rw.11, pela mampang, kota jakarta selatan
# Route distance: 7.2km
#
# Planning route for Pancoran
# Route for vehicle:
#  jl. kalibata tengah xvi no.1, rt.5/rw.9, kalibata, kota jakarta selatan -> jl. warung buncit raya no.1 a, rt.5/rw.3, kalibata, kota jakarta selatan -> jl. warung buncit raya no.25, rt.7/rw.3, kalibata, kota jakarta selatan -> jl. kemang utara ix no.1, rt.2/rw.5, duren tiga, kota jakarta selatan -> jl. pancoran barat vii no.9a, rt.8/rw.1, duren tiga, kota jakarta selatan -> jl. pancoran barat vii no.34, rt.8/rw.6, duren tiga, kota jakarta selatan -> jl. pancoran barat vii, rt. 013 / rw. 006, pancoran, mampang prapatan, rt.12/rw.6, pancoran, kota jakarta selatan -> jalan duren tiga barat no.32, rt.1/rw.1, duren tiga, pancoran, rt.1/rw.1, pancoran, kota jakarta selatan -> jl. kalibata tengah no.1a, rt.5/rw.7, kalibata, kota jakarta selatan -> prrq+c2r, jl. duren tiga selatan, rt.8/rw.2, kalibata, kota jakarta selatan -> jl. kalibata tengah xvi no.1, rt.5/rw.9, kalibata, kota jakarta selatan
# Route distance: 8.5km
#
# Planning route for Pasar Minggu
# Route for vehicle:
#  jl. jeruk purut no.22, rt.3/rw.3, cilandak tim., kota jakarta selatan -> jalan ampera raya 2, rt.2/rw.2, cilandak tim., kota jakarta selatan -> 5, jl. ampera raya no.135, rt.5/rw.10, ragunan, kota jakarta selatan -> pr38+55x, jl. raya cilandak kko, rt.1/rw.5, ragunan, kota jakarta selatan -> jl. raya cilandak kko no.3, rt.14/rw.8, ragunan, kota jakarta selatan -> jl. kebagusan raya no.56, rt.10/rw.4, kebagusan, kota jakarta selatan -> mrpg+f62, rt.10/rw.7, ragunan, south jakarta city -> jl. gurame raya no.32, rt.2/rw.9, ps. minggu, kota jakarta selatan -> apartement kebagusan city tower c unitk18192223, rt.1/rw.6, kebagusan, south jakarta city -> jl. raya ps. minggu no.15d, rt.13/rw.5, ps. minggu, kota jakarta selatan -> jl. jeruk purut no.22, rt.3/rw.3, cilandak tim., kota jakarta selatan
# Route distance: 26.9km
#
# Planning route for Pesanggrahan
# Route for vehicle:
#  jl. garuda no.27, rt.5/rw.6, pesanggrahan, kota jakarta selatan -> jl. damai no:71 rt 005/ rw 005, petukangan selatan, pasanggrahan, rt.7/rw.5, south petukangan, south jakarta city -> jl. m.saidi raya no: 62 rt. 009 / rw. 01, petukangan selatan, pasanggrahan, rt.7/rw.5, petukangan sel., kota jakarta selatan -> jl. ciledug raya no.51, rt.6/rw.4, petukangan utara, kota jakarta selatan -> jl. ciledug raya no.59, rt.1/rw.3, ulujami, kota jakarta selatan -> jl. ulujami raya no.11, rt.11/rw.5, ulujami, kota jakarta selatan -> jl. swadarma raya blok haji nuh 1 no.9, rt.10/rw.3, ulujami, kota jakarta selatan -> jl. swadarma raya no 26 rt 001 rw 008, rt.11/rw.5, ulujami, south jakarta city -> jl. anggrek, rt.7/rw.5, petukangan utara, kota jakarta selatan -> no., jl. m. saidi raya no.54, rt.1/rw.5, petukangan sel., kota jakarta selatan -> jl. garuda no.27, rt.5/rw.6, pesanggrahan, kota jakarta selatan
# Route distance: 9.8km
#
# Planning route for Setiabudi
# Route for vehicle:
#  jl. bek murad no.36, rw.1, kuningan, karet kuningan, kota jakarta selatan -> jalan professor doktor satrio no.289, karet kuningan, setiabudi rt.1/rw.1, kuningan, rt.1/rw.1, kuningan, karet kuningan, south jakarta city -> jalan guru mughni no. c4, karet semanggi, setiabudi, rt.5/rw.2, karet semanggi, rt.5/rw.2, karet semanggi, kota jakarta selatan -> patra jasa, jl. gatot subroto, rt.6/rw.3, kuningan, kuningan tim., kota jakarta selatan -> qrhm+g56, rt.2/rw.5, karet kuningan, south jakarta city -> jl. karet pedurenan no.68a, rt.9/rw.4, kuningan, karet kuningan, kota jakarta selatan -> jl. pedurenan masjid iii no.50, rt.8/rw.4, kuningan, karet kuningan, kota jakarta selatan -> jl. prof. dr. satrio no.18, rt.11/rw.4, kuningan, karet kuningan, kota jakarta selatan -> jl. prof. dr. satrio no.63, rt.11/rw.4, kuningan, karet kuningan, kota jakarta selatan -> 6, jl. denpasar no.7, rt.6/rw.7, kuningan, karet kuningan, kota jakarta selatan -> jl. bek murad no.36, rw.1, kuningan, karet kuningan, kota jakarta selatan
# Route distance: 13.2km
#
# Planning route for Tebet
# Route for vehicle:
#  jl. prof supomo no 321 blok bz persil no 19, rt.13/rw.2, tebet barat, rt.13/rw.2, tebet bar., kota jakarta selatan -> jl. tebet barat dalam ivd no.88, rw.6, tebet bar., kota jakarta selatan -> jl. prof. dr. soepomo no.02, rt.14/rw.6, tebet bar., kota jakarta selatan -> jl. rasamala raya no.26, rt.7/rw.9, menteng dalam, kota jakarta selatan -> qr9v+2q4, jalan dr. soepomo, rt.1/rw.3, menteng dalam, kota jakarta selatan -> jl. pal batu raya no.36, rt.13/rw.4, menteng dalam, kota jakarta selatan -> jalan casablanca, rt. 07 / rw. 11, menteng dalam, tebet, rt.7/rw.11, menteng dalam, kota jakarta selatan -> wisma staco, jl. raya casablanca no.4, rt.4/rw.12, menteng dalam, kota jakarta selatan -> jl. raya casablanca no.14, rw.5, menteng dalam, kota jakarta selatan -> jl. albarkah no.20, rt.7/rw.3, manggarai sel., kota jakarta selatan -> jl. prof supomo no 321 blok bz persil no 19, rt.13/rw.2, tebet barat, rt.13/rw.2, tebet bar., kota jakarta selatan
# Route distance: 12.9km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfde8f92e3212688dc1a3525959960c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfde8f92e3212688dc1a3525959960c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfde8f92e3212688dc1a3525959960c9 = L.map(
#                 &quot;map_dfde8f92e3212688dc1a3525959960c9&quot;,
#                 {
#                     center: [-6.2247397, 106.8447512],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9fa942f042dfee6dcf175ee6c584dd0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e9fa942f042dfee6dcf175ee6c584dd0.addTo(map_dfde8f92e3212688dc1a3525959960c9);
#
#
#             var poly_line_ee6081ee5e3f8defc116a4af9da7d90c = L.polyline(
#                 [[-6.2289516, 106.8473589], [-6.2305878, 106.8468515], [-6.2312211, 106.8461648], [-6.2320594, 106.8460154], [-6.2322374, 106.8461836], [-6.2328524, 106.846492], [-6.233979, 106.8465727], [-6.2356057, 106.8466764], [-6.2370631, 106.8471024], [-6.2371843, 106.8471385], [-6.2392271, 106.8476883]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dfde8f92e3212688dc1a3525959960c9);
#
#
#             ant_path_725f789e9221773cb88b6b2446392d7c = L.polyline.antPath(
#               [[-6.2289516, 106.8473589], [-6.2305878, 106.8468515], [-6.2312211, 106.8461648], [-6.2320594, 106.8460154], [-6.2322374, 106.8461836], [-6.2328524, 106.846492], [-6.233979, 106.8465727], [-6.2356057, 106.8466764], [-6.2370631, 106.8471024], [-6.2371843, 106.8471385], [-6.2392271, 106.8476883]],
#               {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: [10, 50], &quot;dashOffset&quot;: null, &quot;delay&quot;: 500, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;hardwareAcceleration&quot;: false, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;paused&quot;: false, &quot;pulseColor&quot;: &quot;#FFFFFF&quot;, &quot;reverse&quot;: false, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#         ).addTo(map_dfde8f92e3212688dc1a3525959960c9);
#
#
#             var poly_line_4c27278852d834832cee5a35a35fce54 = L.polyline(
#                 [[-6.2392271, 106.8476883], [-6.2371843, 106.8471385], [-6.2370631, 106.8471024], [-6.2371966, 106.8466557], [-6.2373323, 106.8450201], [-6.2373675, 106.8444731], [-6.2379026, 106.8446696], [-6.2395822, 106.8455282]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dfde8f92e3212688dc1a3525959960c9);
#
#
#             ant_path_a510777ba40f9d76d7f580966c15dc82 = L.polyline.antPath(
#               [[-6.2392271, 106.8476883], [-6.2371843, 106.8471385], [-6.2370631, 106.8471024], [-6.2371966, 106.8466557], [-6.2373323, 106.8450201], [-6.2373675, 106.8444731], [-6.2379026, 106.8446696], [-6.2395822, 106.8455282]],
#               {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: [10, 50], &quot;dashOffset&quot;: null, &quot;delay&quot;: 500, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;hardwareAcceleration&quot;: false, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;paused&quot;: false, &quot;pulseColor&quot;: &quot;#FFFFFF&quot;, &quot;reverse&quot;: false, &quot;smoothFactor&quot;: 1.0, &q

# %%
df_filtered
# Out:
#                         nama_tempat  rating_tempat  user_ratings_total
# 0                         indomaret            4.3                 104  \
# 1                         indomaret            0.0                   0
# 2                indomaret bdn raya            4.2                  66
# 3                         indomaret            4.7                   3
# 4      indomaret karang tengah raya            4.3                 108
# ..                              ...            ...                 ...
# 613   indomaret tebet barat in tk29            4.2                 149
# 614           indomaret pal batu 36            4.3                  70
# 615                       indomaret            4.2                 421
# 616             indomaret al barkah            4.6                  18
# 617  indomaret apartemen casablanca            1.0                   1
#
#           lat         lng                                      alamat_tempat
# 0   -6.302203  106.791936  jl. lb. bulus iii no.40, rt.9/rw.7, cilandak b...  \
# 1   -6.307003  106.793690    10, rt.4/rw.10, pondok labu, south jakarta city
# 2   -6.279392  106.798442  jl. bdn raya no.10, rt.10/rw.11, cilandak bar....
# 3   -6.278223  106.797096  jl. rs. fatmawati raya no.7, rt.8/rw.6, gandar...
# 4   -6.301344  106.780550  bona indah plaza, jl. karang tengah raya no.1,...
# ..        ...         ...                                                ...
# 613 -6.238346  106.847226  jl. tebet barat dalam ivd no.88, rw.6, tebet b...
# 614 -6.224740  106.844751  jl. pal batu raya no.36, rt.13/rw.4, menteng d...
# 615 -6.229205  106.847449  jl. prof supomo no 321 blok bz persil no 19, r...
# 616 -6.220490  106.847233  jl. albarkah no.20, rt.7/rw.3, manggarai sel.,...
# 617 -6.223299  106.845345  jl. raya casablanca no.14, rw.5, menteng dalam...
#
#                         place_id      store                   place_id.1
# 0    ChIJaxj8TyDuaS4RmJ8rDkpB2GA  Indomaret  ChIJaxj8TyDuaS4RmJ8rDkpB2GA  \
# 1    ChIJPz4W5BPvaS4RoUnKBAiaL3o  Indomaret  ChIJPz4W5BPvaS4RoUnKBAiaL3o
# 2    ChIJKZqyypTxaS4RkjwUtyXrkBY  Indomaret  ChIJKZqyypTxaS4RkjwUtyXrkBY
# 3    ChIJzVqDlcTxaS4Rwlnqrz5hXbo  Indomaret  ChIJzVqDlcTxaS4Rwlnqrz5hXbo
# 4    ChIJ7aqqqinuaS4RKy68g0RuyMk  Indomaret  ChIJ7aqqqinuaS4RKy68g0RuyMk
# ..                           ...        ...                          ...
# 613  ChIJ7ahV373zaS4Rm9rs7VrGTVg  Indomaret  ChIJ7ahV373zaS4Rm9rs7VrGTVg
# 614  ChIJtX8wqY3zaS4RTpmMPQzAFbg  Indomaret  ChIJtX8wqY3zaS4RTpmMPQzAFbg
# 615  ChIJxf__P5bzaS4RZ7KfkYohoDc  Indomaret  ChIJxf__P5bzaS4RZ7KfkYohoDc
# 616  ChIJk___P4nzaS4RKHnkXKOuy64  Indomaret  ChIJk___P4nzaS4RKHnkXKOuy64
# 617  ChIJV4P3VhjzaS4RnuDMhqW9W2w  Indomaret  ChIJV4P3VhjzaS4RnuDMhqW9W2w
#
#         nama_kelurahan nama_kecamatan             nama_kota
# 0       Cilandak Barat       Cilandak  Kota Jakarta Selatan
# 1          Pondok Labu       Cilandak  Kota Jakarta Selatan
# 2       Cilandak Barat       Cilandak  Kota Jakarta Selatan
# 3     Gandaria Selatan       Cilandak  Kota Jakarta Selatan
# 4          Lebak Bulus       Cilandak  Kota Jakarta Selatan
# ..                 ...            ...                   ...
# 613        Tebet Barat          Tebet  Kota Jakarta Selatan
# 614      Menteng Dalam          Tebet  Kota Jakarta Selatan
# 615        Tebet Barat          Tebet  Kota Jakarta Selatan
# 616  Manggarai Selatan          Tebet  Kota Jakarta Selatan
# 617      Menteng Dalam          Tebet  Kota Jakarta Selatan
#
# [100 rows x 12 columns]

# %%
CENTER_LOCATION = (-6.223299	,106.845345)

# %%
# Create map object
m = folium.Map(location=CENTER_LOCATION, zoom_start=16)

# Plot depot
depot_coords = (G.nodes[depot]['y'], G.nodes[depot]['x'])
folium.Marker(location=depot_coords, icon=folium.Icon(color='red', icon='home', prefix='fa'), tooltip=f"Depot {depot_coords}").add_to(m)

# Plot bus stops
for index, bus_stop in bus_stops.iterrows():
    stop_coords = (bus_stop.geometry.y, bus_stop.geometry.x)
    folium.Marker(location=stop_coords, icon=folium.Icon(color='green', icon='bus', prefix='fa'), tooltip=f"Bus Stop {stop_coords}").add_to(m)

# Create colors for routes
colors = ['blue', 'orange', 'purple', 'green']

# Plot routes
for vehicle_id in range(NUM_VEHICLES):
    index = routing.Start(vehicle_id)
    route = []
    while not routing.IsEnd(index):
        node_index = manager.IndexToNode(index)
        route.append(nodes[node_index])
        index = solution.Value(routing.NextVar(index))
    route.append(nodes[manager.IndexToNode(index)])
    color = colors[vehicle_id % NUM_VEHICLES]
    # Create a list of line segments for the route
    segments = []
    for i in range(len(route)-1):
        # Get shortest path between nodes
        path = nx.shortest_path(G, route[i], route[i + 1], weight='length')
        # Add line segment to list
        segments.append([(G.nodes[node]['y'], G.nodes[node]['x']) for node in path])
    # Create polyline from line segments and add to map
    for segment in segments:
        folium.PolyLine(locations=segment, color=color, weight=5).add_to(m)

# Display map
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [50], line 5
#       2 m = folium.Map(location=CENTER_LOCATION, zoom_start=16)
#       4 # Plot depot
# ----> 5 depot_coords = (G.nodes[depot]['y'], G.nodes[depot]['x'])
#       6 folium.Marker(location=depot_coords, icon=folium.Icon(color='red', icon='home', prefix='fa'), tooltip=f"Depot {depot_coords}").add_to(m)
#       8 # Plot bus stops
#
# NameError: name 'G' is not defined
